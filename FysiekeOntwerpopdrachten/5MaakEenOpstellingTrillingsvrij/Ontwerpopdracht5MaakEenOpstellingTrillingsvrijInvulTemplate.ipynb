# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 56     |  |
# | :-------------|:-------------|
# | Student naam Thomas de Ruyter van Steveninck| Student Studienummer 6528244 |
# | Jasper Bom | 6295835 |
# | Student naam 3| Student Studienummer 3 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 56     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 10:45-11:45 | Jasper |
# | ontwerp-eis berekenen| 10:46-11:45 | Thomas|
# | activiteit 1 | eertse iteratie 13:30-15:00 | hele groep |
# | activiteit 2 | eindproduct 15:00-17:00| hele groep |
# | Mijlpaal 1 | 15:00 | ---|
# | Mijlpaal 2 | 17:00 | ---|
# | Pauze 1| 12:30-13:30 | hele groep |
# | Pauze 2| Tijdspanne | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) |  |
# | hoe lang voor één meting |  |
# | verwacht nauwkeurigheid meting |  |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
r = 1/3 # verhouding tussen Am en Av
f = 5 # hz
w = f
w0 = np.sqrt(w**2)/(2)
f_kantel = w0
print(f_kantel)
# Out:
# 2.5

# %%
# Voeg hier je plot in.
f = np.linspace(1,10,1000)
r = 1/(1-((f**2)/((w0)**2)))

log_f0 = f
log_r =(np.abs(r))


plt.figure()
plt.plot(log_f0,log_r,'r-')
plt.xlabel('f in hz')
plt.ylabel('de verhouding tussen Am en Av')
plt.xscale('log')
plt.yscale('log')
plt.title(' f tegen verhouding Am Av')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g = 9.81 #m/s^2
delta_x = g/(w0**2)
print('De minimale delta_X is {} cm' .format(delta_x*100))
# Out:
# De minimale delta_X is 3.9758432461253346 cm

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

dx1 = delta_x
dx2 = delta_x * 2
dx3 = delta_x * 5
m = np.linspace(0,10,100)
C1 = m * g /dx1
C2 = m * g /dx2
C3 = m * g /dx3
plt.figure()
plt.plot(m,C1,label='dx')
plt.plot(m,C2,label='dx*2')
plt.plot(m,C3,label='dx*5')
plt.xlabel('massa in gram')
plt.ylabel('Veerconstante in N*m')
plt.title('massa tegen veerconstante')
plt.legend()
plt.savefig("verschillende-dx.png")
plt.show()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - de massa te veranderen
# - de veerconstante te veranderen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 5

# %% [markdown]
# hier onze schatting:
# ##### onze schatting met met Young-modulus:
# <img src="schatting.jpeg" width="400">

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="IMG_4694.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 5 cm
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# ja onze opstelling heeft een delta x van 6 cm.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# +/- 30 cm aan beide kanten
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# ja, delta x zit boven het minimalen en er is genoeg ruimte om uit te wijken
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
f = np.logspace(-1,1,1000)
w=2*np.pi*f
f0 = w0/(2*np.pi)
r = 1/(1-((f**2)/((w0)**2)))

g = 9.81
delta_x = 0.06
w1 = np.sqrt(g/delta_x)
print(w1)


r1 = 1/(1-((w**2)/((w1)**2)))

plt.figure()
plt.plot(f,np.abs(r))
plt.plot(f,np.abs(r1))
plt.xlabel('f in hz')
plt.ylabel('de verhouding tussen Am en Av')
plt.xscale('log')
plt.yscale('log')
plt.title(' f tegen verhouding Am Av')
plt.savefig("theorie-en-opstelling.png")
plt.show
# Out:
# 12.786711852544423
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
fm = np.array([2.5, 3.5, 4, 4.7, 5.6, 6, 7.3, 7.8, 9.5])
Av = np.array([1, 4.33, 4.1, 6.04, 7.38, 6.1, 5.32, 4.16, 6.58])
Am = np.array([1, 1.05, 0.88, 1.6, 1, 1, 0.38, 0.48, 0.85])

verhouding = Am/Av 

u_f = 0.2
u_verhouding = 0.3


plt.figure()
plt.plot(fm,verhouding,'.', label='data')
plt.plot(f,np.abs(r1),label='verwachting')
plt.xlabel('f')
plt.ylabel('verhouding')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %%
plt.figure()
plt.plot(fm,verhouding,'.', label='data')
plt.plot(f,np.abs(r1),label='verwachting')
plt.errorbar(fm, verhouding, xerr=u_f, yerr=u_verhouding, fmt='o', capsize=5)
plt.xlabel('f')
plt.ylabel('verhouding')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('frequentie in hertz')
plt.ylabel('verhouding tussen Am en Av')
plt.title('Frequentie tegen verhouding')
plt.legend()
plt.savefig("eindresultaat.png")
plt.show()

# %% [markdown]
# leerdoel 1

# %% [markdown]
# <img src="verschillende-dx.png" width="400">
# <img src="theorie-en-opstelling.png" width="400">

# %% [markdown]
# De variable C en m zijn hier de parameters die van toepassing zijn en onze ontwerpruimte bepalen.

# %% [markdown]
# Leerdoel 2

# %% [markdown]
# <img src="eindresultaat.png" width="400">

# %% [markdown]
# <img src="IMG_4694.jpeg" width="400">
